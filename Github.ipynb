# %% [markdown]
# Teste de Funcionamento

# %%
# !git --version
# Out:
# git version 2.34.1

# %% [markdown]
# Criando a conexão com o github local com o remoto

# %%
import os

username = "FellipeOlliveira"
os.environ["GITHUB_USER"] = username

# !git config --global user.name "${GITHUB_USER}"

os.environ["GITHUB_USER"]
# Out:
# 'FellipeOlliveira'

# %%
import os
from getpass import getpass

usermail = getpass()
os.environ["GITHUB_MAIL"] = usermail

# !git config --global user.email "${GITHUB_MAIL}"
# Out:
# ··········

# %%
import os
from getpass import getpass

usertoken = getpass()
os.environ["GITHUB_TOKEN"] = usertoken
# Out:
# ··········

# %%
# !git clone https://github.com/FellipeOlliveira/Github_Notebook.git
# Out:
# Cloning into 'Github_Notebook'...
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 5 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (5/5), done.

# %%
# !git remote set-url origin https://{os.environ["GITHUB_USER"]}:{os.environ["GITHUB_TOKEN"]}@github.com/FellipeOlliveira/Github_Notebook.git

# %%
# !git remote -v

# %%
# %cd Github_Notebook
# Out:
# /content/Github_Notebook

# %% [markdown]
# CRIANDO ARQUIVO PARA TESTAR

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !touch hello.py
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	hello.py
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git add hello.py
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	new file:   hello.py

# %% [markdown]
# Salvando os dados

# %%
# !git commit -m "DOCS: hello.py"
# !git status
# Out:
# [main 656f367] DOCS: hello.py
#  1 file changed, 0 insertions(+), 0 deletions(-)
#  create mode 100644 hello.py
# On branch main
# Your branch is ahead of 'origin/main' by 1 commit.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean

# %%
# !git push origin main
# !git status
# Out:
# Enumerating objects: 4, done.
# Counting objects: 100% (4/4), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (3/3), 280 bytes | 280.00 KiB/s, done.
# Total 3 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/FellipeOlliveira/Github_Notebook.git
#    3b04771..656f367  main -> main
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
